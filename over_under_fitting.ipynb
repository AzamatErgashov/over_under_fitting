# %%
from IPython.display import Image

# %% [markdown]
# # mana bu yerda underfitting va overfitting farqi tushuntirilib berilgan

# %%
Image('over_under.jpg')

# %% [markdown]
# ## underfitting va overfitting interviyularda qayta qayta soraladigan mavzu

# %% [markdown]
# ## underfitting model juda sodda bolib qolganda va train setda ham test setda ham katta hatolik beradi ikkinchi nomi high bias (gumon)

# %%
Image('underfitting.jpg', width=500)

# %% [markdown]
# # overfitting under fittingni teskarisi endi bunda model umuman hato chiqarmaydi

# %%
Image('overfitting.jpg', width=500)

# %% [markdown]
# # mana bu yerdayam korishimiz mumkin qizil chiziq har bir nuqtadan otgan

# %% [markdown]
# # oversettingni mommosiyam shunda judayam moslashib qoladi dataga

# %% [markdown]
# ## train set da hatolik kam test setda judaa katta hatolar chiqa boshladi

# %% [markdown]
# ## ikkinchi nomi high veriance (farq)

# %% [markdown]
# # yaxshi model

# %%
Image('yaxshimodel.jpg', width=500)

# %% [markdown]
# ## mana bu yaxshi model chunki test set ham train set ham bir xil ishlamoqda chiqiqlariyam deyarli ustma ust tushgan

# %% [markdown]
# ## low bias low variance deb aytiladi

# %%
Image('model_farqlari.jpg', width=500)

# %% [markdown]
# ## manabu rasmdan ham korib olsak boladi yomon model non linear regressiya qilish kerak bolgan joyga linearni ozini ishlatib quyilgan yaxshi modelda non linear ishlatilgan data train ga ham testga ham yaxshi ishlamoqda yomon model esa trainni har bir datasiga mos lekin yangi data kelsa hatolik katta

# %% [markdown]
# # BU MUAMMOLARNI QANDAY TO'GIRLAYMIZ?

# %% [markdown]
# # Underfitting - modelni murakkablashtiramiz
# ## koproq parametrlar qoshish
# ## polinomil darajalarini oshirish
# ## koproq qavatlar qoshish (deep learning)

# %% [markdown]
# # Overfitting - modelni soddalashtiramiz
# ## parametrlarni kamaytirish
# ## algoritimni ozgartirish
# ## polinomial darajalarni kamaytirish
# ## koproq malumot yigish
# ##
